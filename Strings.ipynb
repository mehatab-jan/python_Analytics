# %% [markdown]
# <a href="https://colab.research.google.com/github/mehatab-jan/python_Analytics/blob/main/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Strings

# %%
name = input("enter your name:")
print(name)
# Out:
# enter your name:jaan
# jaan

# %%
text = """Hello
Welcome to data analytics"""
print(text)
# Out:
# Hello
# Welcome to data analytics

# %%
word = "Mehatab"

print(word[0])
print(word[1])
print(word[5])
# Out:
# M
# e
# a

# %%
word = "Mehatab"

print(word[-1])
print(word[-2])
print(word[-6])
# Out:
# b
# a
# e

# %%
text = "Programming"

print(text[0:6])
print(text[3:8])
print(text[:5])
print(text[5:])
print(text[::2])
print(text[::-1])
# Out:
# Progra
# gramm
# Progr
# amming
# Pormig
# gnimmargorP

# %%
first = "Hello"
second = "World"
result = first + " " + second

print(result)
# Out:
# Hello World

# %%
print("Hi " * 3)
# Out:
# Hi Hi Hi

# %%
text = "Programming"

print(len(text))
# Out:
# 11

# %%
word = "hello world!"

for ch in word:
    print(ch)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d
# !

# %%
name = "Mehatab"
age = 20

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Mehatab and I am 20 years old.

# %%
word = "hello"

# word[0] = "y"

word = "yello"

print(word)
# Out:
# yello

# %%
text = "Data Analytics"

print(text.upper())
print(text.lower())
print(text.title())
print(text.capitalize())
print(text.swapcase())
print(text.casefold())
# Out:
# DATA ANALYTICS
# data analytics
# Data Analytics
# Data analytics
# dATA aNALYTICS
# data analytics

# %%
text = "I am in agl"

print(text.replace("agl", "gtkl"))
# Out:
# I am in gtkl
