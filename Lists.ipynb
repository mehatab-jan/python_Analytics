# %% [markdown]
# <a href="https://colab.research.google.com/github/mehatab-jan/python_Analytics/blob/main/Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [10, 20, 30, 40]
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
data = [10, "Python", 3.14, True]
print(data)

# %%
letters = list("Mehatab")
print(letters)
# Out:
# ['M', 'e', 'h', 'a', 't', 'a', 'b']

# %%
numbers = [100,200,300,400]

print(numbers[0])
print(numbers[2])
# Out:
# 100
# 300

# %%
numbers = [10,20,30,40,50]

print(numbers[1:4])
print(numbers[:3])
print(numbers[2:])
print(numbers[::-1])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]
# [50, 40, 30, 20, 10]

# %%
numbers = [10,20,30]

numbers[1] = 100

print(numbers)
# Out:
# [10, 100, 30]

# %%
a = [1,2]
b = [3,4]

print(a + b)
# Out:
# [1, 2, 3, 4]

# %%
print([1,2] * 3)
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
numbers = [10,20,30]

print(20 in numbers)
print(50 not in numbers)
# Out:
# True
# True

# %%
numbers = [10,20,30]

print(len(numbers))
# Out:
# 3

# %%
numbers = [10,50,30]

print(max(numbers))
# Out:
# 50

# %%
numbers = [10,50,30]

print(min(numbers))
# Out:
# 10

# %%
numbers = [10,20,30]

print(sum(numbers))
# Out:
# 60

# %%
numbers = [30,10,20]

print(sorted(numbers))
# Out:
# [10, 20, 30]

# %%
numbers = [1,2,3]

print(list(reversed(numbers)))
# Out:
# [3, 2, 1]

# %% [markdown]
# Methods

# %%
numbers = [10,20]
numbers.append(30)
numbers.append(40)
numbers.append(50)
numbers.append(60)
print(numbers)
len(numbers)
# Out:
# [10, 20, 30, 40, 50, 60]
# 6

# %%
numbers = [10,20]
numbers.extend([30,40,50,60])
print(numbers)
len(numbers)
# Out:
# [10, 20, 30, 40, 50, 60]
# 6

# %%
numbers = [100,300]

numbers.insert(1,200)

print(numbers)
# Out:
# [100, 200, 300]

# %%
numbers = [10,20,30,20]

numbers.remove(20)

print(numbers)
# Out:
# [10, 30, 20]

# %%
numbers = [10,20,30]

print(numbers.pop())
print(numbers)
# Out:
# 30
# [10, 20]

# %%
numbers = [10,20,30]

print(numbers.pop())
print(numbers)
# Out:
# 30
# [10, 20]

# %%
numbers = [10,20,30]

numbers.clear()

print(numbers)
# Out:
# []

# %%
numbers = [10,20,30]

print(numbers.index(20))
# Out:
# 1

# %%
numbers = [10,20,20,30]

print(numbers.count(20))
# Out:
# 2

# %%
numbers = [30,10,20]

numbers.sort()

print(numbers)
# Out:
# [10, 20, 30]

# %%
numbers = [1,2,3]

numbers.reverse()

print(numbers)
# Out:
# [3, 2, 1]

# %% [markdown]
# Shallow copy

# %%
numbers = [10,20]

new_list = numbers.copy()

print(new_list)
# Out:
# [10, 20]

# %%
squares = [x*x for x in range(1,6)]

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
a = [1,2,3]

b = a

# %%
print(b)
# Out:
# [1, 2, 3]
